# %%
from utility import *
CheckVersion()
# Out:
# system version: 3.9.16 (main, Dec  7 2022, 01:11:58)
# [GCC 7.5.0]
# matplotlib version: 3.7.1
# numpy version: 1.24.3
# pandas version: 2.0.2
# iminuit version: 2.21.3
# scipy version: 1.10.1
# numba version: 0.57.0
# numba_stats version: 1.2.0
# uproot version: 5.0.8

# %%
# %run run_manager.py
# Out:
# *** merge full run list
# get run list from rawdata dir /mnt/c/Users/tuank/OneDrive - kekdx/LowMassDM/KamiokaCryo/BKG_MiniLAND_rawdata/
# get run list from log file run_log
# *** get run info from rawdata
# ...

# %%
df = pd.read_pickle('run_summary.pkl')
df
# Out:
#     runnumber detector          runtype                  source  \
# 0           9      NaN              NaN                     NaN
# 1          10      NaI  calibration run            source 137Cs
# 2          11      NaI  calibration run            source 137Cs
# 3          12      NaI  calibration run            source 137Cs
# 4          13      NaI  calibration run             source 60Co
# 5          14      NaI       normal run            target floor
# 6          15      NaI       normal run  target wall to KamLAND
# 7          16      NaI       normal run  target wall to KamLAND
# 8          17      NaI       normal run              background
# 9          18      NaI       normal run              background
# 10         19      3He       normal run                    test
# 11         20      3He       normal run                    test
# 12         21      NaI       normal run              background
# 13         22      NaI       normal run              background
# ...
